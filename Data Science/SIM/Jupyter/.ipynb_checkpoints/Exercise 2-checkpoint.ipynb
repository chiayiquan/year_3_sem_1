# %%
#import pandas as pd
import csv as csv
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 import pandas as pd
#       2 import csv as csv
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df2=pd.read_csv('AAPL_stock_price_example.csv', index_col=0)

# %%
df2
# Out:
#                  Close
# Date
# 2019-01-02  157.919998
# 2019-01-03  142.190002
# 2019-01-04  148.259995
# 2019-01-07  147.929993
# 2019-01-08  150.750000
# ...                ...
# 2019-11-20  263.190002
# 2019-11-21  262.010010
# 2019-11-22  261.779999
# 2019-11-25  266.369995
# 2019-11-26  264.290009
#
# [229 rows x 1 columns]

# %%
with open('AAPL_stock_price_example.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    
    print(reader.fieldnames)
    
    data = []
    for row in reader:
        data.append(row)
    
    print(data)
# Out:
# ['Date', 'Close']
# [{'Date': '2019-01-02', 'Close': '157.919998'}, {'Date': '2019-01-03', 'Close': '142.190002'}, {'Date': '2019-01-04', 'Close': '148.259995'}, {'Date': '2019-01-07', 'Close': '147.929993'}, {'Date': '2019-01-08', 'Close': '150.75'}, {'Date': '2019-01-09', 'Close': '153.309998'}, {'Date': '2019-01-10', 'Close': '153.800003'}, {'Date': '2019-01-11', 'Close': '152.289993'}, {'Date': '2019-01-14', 'Close': '150'}, {'Date': '2019-01-15', 'Close': '153.070007'}, {'Date': '2019-01-16', 'Close': '154.940002'}, {'Date': '2019-01-17', 'Close': '155.860001'}, {'Date': '2019-01-18', 'Close': '156.820007'}, {'Date': '2019-01-22', 'Close': '153.300003'}, {'Date': '2019-01-23', 'Close': '153.919998'}, {'Date': '2019-01-24', 'Close': '152.699997'}, {'Date': '2019-01-25', 'Close': '157.759995'}, {'Date': '2019-01-28', 'Close': '156.300003'}, {'Date': '2019-01-29', 'Close': '154.679993'}, {'Date': '2019-01-30', 'Close': '165.25'}, {'Date': '2019-01-31', 'Close': '166.440002'}, {'Date': '2019-02-01', 'Close': '166.520004'}, {'Date': '2019-02-04', 'Close': '171.25'}, {'Date': '2019-02-05', 'Close': '174.179993'}, {'Date': '2019-02-06', 'Close': '174.240005'}, {'Date': '2019-02-07', 'Close': '170.940002'}, {'Date': '2019-02-08', 'Close': '170.410004'}, {'Date': '2019-02-11', 'Close': '169.429993'}, {'Date': '2019-02-12', 'Close': '170.889999'}, {'Date': '2019-02-13', 'Close': '170.179993'}, {'Date': '2019-02-14', 'Close': '170.800003'}, {'Date': '2019-02-15', 'Close': '170.419998'}, {'Date': '2019-02-19', 'Close': '170.929993'}, {'Date': '2019-02-20', 'Close': '172.029999'}, {'Date': '2019-02-21', 'Close': '171.059998'}, {'Date': '2019-02-22', 'Close':
# %% [markdown]
# # Computing simple statistics

# %% [markdown]
# ## 1. Exploring sample texts
#
# Downloaded from nltk

# %%
import nltk

# %%
nltk.download("book")
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to C:\Users\yi
# [nltk_data]    |     quan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\abc.zip.
# [nltk_data]    | Downloading package brown to C:\Users\yi
# [nltk_data]    |     quan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\brown.zip.
# [nltk_data]    | Downloading package chat80 to C:\Users\yi
# [nltk_data]    |     quan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\chat80.zip.
# [nltk_data]    | Downloading package cmudict to C:\Users\yi
# [nltk_data]    |     quan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cmudict.zip.
# [nltk_data]    | Downloading package conll2000 to C:\Users\yi
# [nltk_data]    |     quan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to C:\Users\yi
# ...

# %%
from nltk.book import *

# %%
sents()
# Out:
# sent1: Call me Ishmael .
# sent2: The family of Dashwood had long been settled in Sussex .
# sent3: In the beginning God created the heaven and the earth .
# sent4: Fellow - Citizens of the Senate and of the House of Representatives :
# sent5: I have a problem with people PMing me to lol JOIN
# sent6: SCENE 1 : [ wind ] [ clop clop clop ] KING ARTHUR : Whoa there !
# sent7: Pierre Vinken , 61 years old , will join the board as a nonexecutive director Nov. 29 .
# sent8: 25 SEXY MALE , seeks attrac older single lady , for discreet encounters .
# sent9: THE suburb of Saffron Park lay on the sunset side of London , as red and ragged as a cloud of sunset .

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %% [markdown]
# ## 2. Counting vocabulary

# %%
len(text1)
# Out:
# 260819

# %%
len(text6)
# Out:
# 16967

# %%
set(text1)
# Out:
# {'checkered',
#  'despite',
#  'sleeper',
#  'nape',
#  'babe',
#  'gentlemanlike',
#  'leisurely',
#  'Ireland',
#  'supplies',
#  'ripening',
#  'rafters',
#  'WATCH',
#  'Assume',
#  'serving',
#  'Paint',
#  'carriages',
#  'plain',
#  'fixedly',
#  'Usually',
#  'dipped',
#  'idiom',
#  'intermeddling',
#  'intensified',
#  'saw',
#  'aspect',
#  'tastefully',
#  'protesting',
#  'hamlets',
#  'commentator',
#  'Vengeance',
#  'herding',
#  'gibberish',
#  'torrents',
#  'unawares',
#  'agony',
#  'metal',
#  'contemplative',
#  'accommodated',
#  'reigneth',
#  'sullenly',
#  'pepper',
#  'demonstrations',
#  'pantaloon',
#  'ceremonial',
#  'conjures',
#  'CLOSES',
#  'habituated',
#  'crowd',
#  'Laws',
#  'John',
#  'deceits',
#  'harem',
#  'destined',
#  'Babylonian',
#  'overspreading',
#  'pave',
#  'peasant',
#  'contemporary',
#  'Shipmates',
#  'securities',
#  'unobtrusive',
#  'hail',
#  'hope',
#  'banqueter',
#  'diabolism',
#  'fuzzing',
#  'rebounds',
# ...

# %%
sorted(set(text1))
# Out:
# ['!',
#  '!"',
#  '!"--',
#  "!'",
#  '!\'"',
#  '!)',
#  '!)"',
#  '!*',
#  '!--',
#  '!--"',
#  "!--'",
#  '"',
#  '"\'',
#  '"--',
#  '"...',
#  '";',
#  '$',
#  '&',
#  "'",
#  "',",
#  "',--",
#  "'-",
#  "'--",
#  "';",
#  '(',
#  ')',
#  '),',
#  ')--',
#  ').',
#  ').--',
#  '):',
#  ');',
#  ');--',
#  '*',
#  ',',
#  ',"',
#  ',"--',
#  ",'",
#  ",'--",
#  ',)',
#  ',*',
#  ',--',
#  ',--"',
#  ",--'",
#  '-',
#  '--',
#  '--"',
#  "--'",
#  '--\'"',
#  '--(',
#  '---"',
#  '---,',
#  '.',
#  '."',
#  '."*',
#  '."--',
#  ".'",
#  '.\'"',
#  '.)',
#  '.*',
#  '.*--',
#  '.,',
#  '.--',
#  '.--"',
#  '...',
#  '....',
#  '.]',
#  '000',
#  '1',
#  '10',
#  '100',
#  '101',
#  '102',
#  '103',
#  '104',
#  '105',
#  '106',
#  '107',
#  '108',
#  '109',
#  '11',
#  '110',
#  '111',
#  '112',
#  '113',
#  '114',
#  '115',
#  '116',
#  '117',
#  '118',
#  '119',
#  '12',
#  '120',
#  '121',
#  '122',
#  '123',
#  '124',
#  '125',
#  '126',
#  '127',
#  '128',
#  '129',
#  '13',
# ...

# %%
len(sorted(set(text1)))
# Out:
# 19317

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)

# %%
lexical_diversity(text1)
# Out:
# 0.07406285585022564

# %% [markdown]
# ## 3. Frequency distributions
#
# Power laws in language

# %%
f = FreqDist(text1)

# %%
f
# Out:
# FreqDist({',': 18713, 'the': 13721, '.': 6862, 'of': 6536, 'and': 6024, 'a': 4569, 'to': 4542, ';': 4072, 'in': 3916, 'that': 2982, ...})

# %%
f.most_common(10)
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982)]

# %%
f['love']
# Out:
# 24

# %%
f.plot(50,cumulative=False)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ## 4. Collocations
#
# Words that 'stick together'

# %%
text1.collocations()
# Out:
# Sperm Whale; Moby Dick; White Whale; old man; Captain Ahab; sperm
# whale; Right Whale; Captain Peleg; New Bedford; Cape Horn; cried Ahab;
# years ago; lower jaw; never mind; Father Mapple; cried Stubb; chief
# mate; white whale; ivory leg; one hand

# %%
text6.collocations()
# Out:
# BLACK KNIGHT; clop clop; HEAD KNIGHT; mumble mumble; Holy Grail;
# squeak squeak; FRENCH GUARD; saw saw; Sir Robin; Run away; CARTOON
# CHARACTER; King Arthur; Iesu domine; Pie Iesu; DEAD PERSON; Round
# Table; clap clap; OLD MAN; dramatic chord; dona eis

# %%
f = FreqDist([len(w) for w in text1])

# %%
f
# Out:
# FreqDist({3: 50223, 1: 47933, 4: 42345, 2: 38513, 5: 26597, 6: 17111, 7: 14399, 8: 9966, 9: 6428, 10: 3528, ...})

# %%
f.keys()
# Out:
# dict_keys([1, 4, 2, 6, 8, 9, 11, 5, 7, 3, 10, 12, 13, 14, 16, 15, 17, 18, 20])

# %%
f.hapaxes()
# Out:
# [18, 20]
